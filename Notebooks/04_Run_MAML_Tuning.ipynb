# %%
import os
if os.getcwd() == '/Users/george/Desktop/MLFG_Project/Notebooks':
    os.chdir('..')

# %%
import sys
sys.path.append('learn2learn/') # the version on pypi doesn't have LightningMAML ==> doing submodule approach
                                # its a little gross--> hopefully this can be change in the near future
# %config Completer.use_jedi = False

# %%
from datasets import load_abundance_data, get_shared_taxa_dfs
from datasets import MicroDataset, Dataset
from Metalearning.MAML import tune_MAML_FFNN
import torch.nn.functional as F
import pandas as pd
import numpy as np
dfs = load_abundance_data()
all_datasets = get_shared_taxa_dfs(dfs)

# %%
def tune_across_shared_datasets(dataset_list,
                                model_name,
                                tuning_func,
                                path, 
                                is_marker):
    if os.path.isfile(path):
        raise(ValueError('Will not run function and potentially overwrite important results! Either delete or move the file first'))
    
    # initialize csv to store results in
    results=pd.DataFrame(columns =  ['Model Type', 'Data Type', 'Dataset', 'hyperparams', 'AUC'])
    results.to_csv(path, index=False)
    # function to loop the tuning functions across each dataset
    for i in range(len(dataset_list)):
        datas = dataset_list[i:] + dataset_list[:i]
        print(datas[0].index[0])
        results=tuning_func(datas, 
                            is_marker=is_marker)
        results = pd.DataFrame([a if type(a)==str 
                                 else [b for c,b in a.items()] if type(a) == dict 
                                 else a[0]['objective'] if type(a)==tuple
                                 else a
                                 for a in results]).T
        results.columns=['Model Type', 'Data Type', 'Dataset', 'hyperparams', 'AUC']
        pd.concat( [pd.read_csv(path),results], axis=0 ).to_csv(path, index=False)
        print('Dataset #'+str(i)+' complete!')

# %%
names = ['Obesity', 'Colorectal', 'IBD', 'EW-T2D','C-T2D', 'Cirrhosis']
#creating different groups for param sharing
groups = {
          'EU': ['Obesity', 'Colorectal', 'IBD', 'EW-T2D'],
          'CH':['C-T2D', 'Cirrhosis'], 
          'T2D':['EW-T2D','C-T2D'],
          'Colon':['Colorectal','IBD']
         }

# %%
# %time
i = 0
mod = 'FFNN'
for g in groups:
    subset_names = groups[g]
    ds = [all_datasets[s] for s in subset_names]
    path = 'results/MAML_results/' + g + '_MAML_' + mod + '.csv'
    tune_across_shared_datasets(ds,
                                mod,
                                tune_MAML_FFNN,
                                path, 
                                is_marker=False
                                 )
# Out:
# [INFO 04-18 10:00:26] ax.modelbridge.dispatch_utils: Using Sobol generation strategy.
# [INFO 04-18 10:00:26] ax.service.managed_loop: Started full optimization with 15 steps.
# [INFO 04-18 10:00:26] ax.service.managed_loop: Running optimization trial 1...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 5.72 µs
# 0
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 10:02:31] ax.service.managed_loop: Running optimization trial 2...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 10:04:41] ax.service.managed_loop: Running optimization trial 3...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 10:07:57] ax.service.managed_loop: Running optimization trial 4...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 10:10:16] ax.service.managed_loop: Running optimization trial 5...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 10:10:58] ax.service.managed_loop: Running optimization trial 6...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 10:11:26] ax.service.managed_loop: Running optimization trial 7...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 10:11:42] ax.service.managed_loop: Running optimization trial 8...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 10:12:31] ax.service.managed_loop: Running optimization trial 9...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 10:13:44] ax.service.managed_loop: Running optimization trial 10...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 10:17:54] ax.service.managed_loop: Running optimization trial 11...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 10:20:12] ax.service.managed_loop: Running optimization trial 12...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 10:27:02] ax.service.managed_loop: Running optimization trial 13...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 10:41:28] ax.service.managed_loop: Running optimization trial 14...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 10:41:47] ax.service.managed_loop: Running optimization trial 15...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 10:45:59] ax.modelbridge.dispatch_utils: Using Sobol generation strategy.
# [INFO 04-18 10:45:59] ax.service.managed_loop: Started full optimization with 15 steps.
# [INFO 04-18 10:45:59] ax.service.managed_loop: Running optimization trial 1...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# Dataset #0 complete!
# 353
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 10:48:00] ax.service.managed_loop: Running optimization trial 2...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 10:50:34] ax.service.managed_loop: Running optimization trial 3...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 10:54:03] ax.service.managed_loop: Running optimization trial 4...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 10:54:57] ax.service.managed_loop: Running optimization trial 5...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 10:59:41] ax.service.managed_loop: Running optimization trial 6...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 11:05:37] ax.service.managed_loop: Running optimization trial 7...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 11:13:03] ax.service.managed_loop: Running optimization trial 8...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 11:14:15] ax.service.managed_loop: Running optimization trial 9...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 11:14:40] ax.service.managed_loop: Running optimization trial 10...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 11:19:08] ax.service.managed_loop: Running optimization trial 11...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 11:27:58] ax.service.managed_loop: Running optimization trial 12...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 11:28:54] ax.service.managed_loop: Running optimization trial 13...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 11:35:51] ax.service.managed_loop: Running optimization trial 14...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 11:37:46] ax.service.managed_loop: Running optimization trial 15...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# Dataset #1 complete!

# %%
# subset_names = groups[g]
ds = [all_datasets[s] for s in names]
path = 'results/MAML_results/' + 'ALL' + '_MAML_' + mod + '.csv'
tune_across_shared_datasets(ds,
                            mod,
                            tune_MAML_FFNN,
                            path, 
                            is_marker=False
                             )
# Out:
# [INFO 04-18 11:38:12] ax.modelbridge.dispatch_utils: Using Sobol generation strategy.
# [INFO 04-18 11:38:12] ax.service.managed_loop: Started full optimization with 15 steps.
# [INFO 04-18 11:38:12] ax.service.managed_loop: Running optimization trial 1...
# 830
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 11:39:51] ax.service.managed_loop: Running optimization trial 2...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 11:40:26] ax.service.managed_loop: Running optimization trial 3...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 11:41:26] ax.service.managed_loop: Running optimization trial 4...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 11:44:24] ax.service.managed_loop: Running optimization trial 5...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 11:44:44] ax.service.managed_loop: Running optimization trial 6...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 11:45:20] ax.service.managed_loop: Running optimization trial 7...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 11:53:36] ax.service.managed_loop: Running optimization trial 8...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 11:54:52] ax.service.managed_loop: Running optimization trial 9...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 11:55:32] ax.service.managed_loop: Running optimization trial 10...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 11:58:46] ax.service.managed_loop: Running optimization trial 11...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 11:59:46] ax.service.managed_loop: Running optimization trial 12...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 12:03:18] ax.service.managed_loop: Running optimization trial 13...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 12:04:07] ax.service.managed_loop: Running optimization trial 14...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 12:06:48] ax.service.managed_loop: Running optimization trial 15...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 12:13:40] ax.modelbridge.dispatch_utils: Using Sobol generation strategy.
# [INFO 04-18 12:13:40] ax.service.managed_loop: Started full optimization with 15 steps.
# [INFO 04-18 12:13:40] ax.service.managed_loop: Running optimization trial 1...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# Dataset #0 complete!
# 0
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 12:14:43] ax.service.managed_loop: Running optimization trial 2...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 12:15:24] ax.service.managed_loop: Running optimization trial 3...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 12:17:26] ax.service.managed_loop: Running optimization trial 4...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 12:18:31] ax.service.managed_loop: Running optimization trial 5...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 12:20:49] ax.service.managed_loop: Running optimization trial 6...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 12:31:43] ax.service.managed_loop: Running optimization trial 7...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 12:32:48] ax.service.managed_loop: Running optimization trial 8...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 12:33:39] ax.service.managed_loop: Running optimization trial 9...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 12:42:07] ax.service.managed_loop: Running optimization trial 10...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 12:42:39] ax.service.managed_loop: Running optimization trial 11...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 12:43:01] ax.service.managed_loop: Running optimization trial 12...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 12:43:20] ax.service.managed_loop: Running optimization trial 13...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 12:44:59] ax.service.managed_loop: Running optimization trial 14...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 12:46:01] ax.service.managed_loop: Running optimization trial 15...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 12:46:49] ax.modelbridge.dispatch_utils: Using Sobol generation strategy.
# [INFO 04-18 12:46:49] ax.service.managed_loop: Started full optimization with 15 steps.
# [INFO 04-18 12:46:49] ax.service.managed_loop: Running optimization trial 1...
# Dataset #1 complete!
# 353
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 12:51:09] ax.service.managed_loop: Running optimization trial 2...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 12:51:55] ax.service.managed_loop: Running optimization trial 3...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 12:52:20] ax.service.managed_loop: Running optimization trial 4...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 12:52:53] ax.service.managed_loop: Running optimization trial 5...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 12:54:51] ax.service.managed_loop: Running optimization trial 6...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 12:55:13] ax.service.managed_loop: Running optimization trial 7...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 12:56:05] ax.service.managed_loop: Running optimization trial 8...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 12:58:32] ax.service.managed_loop: Running optimization trial 9...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 12:59:09] ax.service.managed_loop: Running optimization trial 10...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 12:59:48] ax.service.managed_loop: Running optimization trial 11...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 13:03:37] ax.service.managed_loop: Running optimization trial 12...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 13:04:15] ax.service.managed_loop: Running optimization trial 13...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 13:04:39] ax.service.managed_loop: Running optimization trial 14...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 13:05:11] ax.service.managed_loop: Running optimization trial 15...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 13:06:43] ax.modelbridge.dispatch_utils: Using Sobol generation strategy.
# [INFO 04-18 13:06:43] ax.service.managed_loop: Started full optimization with 15 steps.
# [INFO 04-18 13:06:43] ax.service.managed_loop: Running optimization trial 1...
# Dataset #2 complete!
# 734
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 13:07:16] ax.service.managed_loop: Running optimization trial 2...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 13:15:33] ax.service.managed_loop: Running optimization trial 3...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 13:16:09] ax.service.managed_loop: Running optimization trial 4...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 13:16:42] ax.service.managed_loop: Running optimization trial 5...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 13:16:59] ax.service.managed_loop: Running optimization trial 6...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 13:18:22] ax.service.managed_loop: Running optimization trial 7...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 13:19:39] ax.service.managed_loop: Running optimization trial 8...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 13:20:56] ax.service.managed_loop: Running optimization trial 9...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 13:22:00] ax.service.managed_loop: Running optimization trial 10...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 13:22:28] ax.service.managed_loop: Running optimization trial 11...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 13:26:07] ax.service.managed_loop: Running optimization trial 12...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 13:26:30] ax.service.managed_loop: Running optimization trial 13...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 13:27:13] ax.service.managed_loop: Running optimization trial 14...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 13:28:34] ax.service.managed_loop: Running optimization trial 15...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 13:29:06] ax.modelbridge.dispatch_utils: Using Sobol generation strategy.
# [INFO 04-18 13:29:06] ax.service.managed_loop: Started full optimization with 15 steps.
# [INFO 04-18 13:29:06] ax.service.managed_loop: Running optimization trial 1...
# Dataset #3 complete!
# 463
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 13:31:54] ax.service.managed_loop: Running optimization trial 2...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 13:32:19] ax.service.managed_loop: Running optimization trial 3...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 13:37:35] ax.service.managed_loop: Running optimization trial 4...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 13:41:37] ax.service.managed_loop: Running optimization trial 5...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 13:42:25] ax.service.managed_loop: Running optimization trial 6...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 13:42:41] ax.service.managed_loop: Running optimization trial 7...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 13:47:07] ax.service.managed_loop: Running optimization trial 8...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 13:48:04] ax.service.managed_loop: Running optimization trial 9...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 13:48:27] ax.service.managed_loop: Running optimization trial 10...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 13:53:23] ax.service.managed_loop: Running optimization trial 11...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 13:58:54] ax.service.managed_loop: Running optimization trial 12...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 14:01:02] ax.service.managed_loop: Running optimization trial 13...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 14:01:20] ax.service.managed_loop: Running optimization trial 14...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 14:02:50] ax.service.managed_loop: Running optimization trial 15...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 14:12:45] ax.modelbridge.dispatch_utils: Using Sobol generation strategy.
# [INFO 04-18 14:12:45] ax.service.managed_loop: Started full optimization with 15 steps.
# [INFO 04-18 14:12:45] ax.service.managed_loop: Running optimization trial 1...
# Dataset #4 complete!
# 121
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 14:13:59] ax.service.managed_loop: Running optimization trial 2...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 14:20:22] ax.service.managed_loop: Running optimization trial 3...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 14:21:01] ax.service.managed_loop: Running optimization trial 4...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 14:30:02] ax.service.managed_loop: Running optimization trial 5...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 14:31:19] ax.service.managed_loop: Running optimization trial 6...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 14:32:11] ax.service.managed_loop: Running optimization trial 7...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 14:33:15] ax.service.managed_loop: Running optimization trial 8...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 14:38:12] ax.service.managed_loop: Running optimization trial 9...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 14:46:58] ax.service.managed_loop: Running optimization trial 10...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 14:50:48] ax.service.managed_loop: Running optimization trial 11...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 14:52:14] ax.service.managed_loop: Running optimization trial 12...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 14:52:54] ax.service.managed_loop: Running optimization trial 13...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 14:54:12] ax.service.managed_loop: Running optimization trial 14...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# [INFO 04-18 14:54:55] ax.service.managed_loop: Running optimization trial 15...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# Dataset #5 complete!
